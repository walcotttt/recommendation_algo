# %%
# import modules

import pandas as pd
import numpy as np

# %%
# load in dataset 
df = pd.read_csv("train.csv")

# %%
# removing unnecessary columns

to_drop = ['Unnamed: 0',
           'artist_name'
           'track_name'
           'lyrics',
           'age']

df.drop(to_drop, inplace=True, axis=1)

# %%
# renaming columns 
new_names =  {'shake the audience': 'shake_the_audience'}

df.rename(columns=new_names, inplace=True)

# %%
df.head()
# Out:
#             artist_name            track_name  release_date genre  len  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop   95
# 1         frankie laine             i believe          1950   pop   51
# 2           johnnie ray                   cry          1950   pop   24
# 3           pérez prado              patricia          1950   pop   54
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop   48
#
#      dating  violence  world/life  night/time  shake_the_audience  ...  \
# 0  0.000598  0.063746    0.000598    0.000598            0.000598  ...
# 1  0.035537  0.096777    0.443435    0.001284            0.001284  ...
# 2  0.002770  0.002770    0.002770    0.002770            0.002770  ...
# 3  0.048249  0.001548    0.001548    0.001548            0.021500  ...
# 4  0.001350  0.001350    0.417772    0.001350            0.001350  ...
#
#    romantic  communication   obscene     music  movement/places  \
# 0  0.017104       0.263751  0.000598  0.039288         0.000598
# 1  0.001284       0.001284  0.001284  0.118034         0.001284
# 2  0.158564       0.250668  0.002770  0.323794         0.002770
# 3  0.411536       0.001548  0.001548  0.001548         0.129250
# 4  0.463430       0.001350  0.001350  0.001350         0.001350
#
#    light/visual perceptions  family/spiritual   sadness  feelings       topic
# 0                  0.000598          0.000598  0.380299  0.117175     sadness
# 1                  0.212681          0.051124  0.001284  0.001284  world/life
# 2                  0.002770          0.002770  0.002770  0.225422       music
# 3                  0.001548          0.001548  0.225889  0.001548    romantic
# 4                  0.001350          0.029755  0.068800  0.001350    romantic
#
# [5 rows x 21 columns]

# %%
# one hot encode genre & topic
